# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
a=[1,2,3,5,8]
b=[2,3,4,9,0]

plt.plot(a,b)
plt.title("line")
plt.show()

# %%
from matplotlib import style
style.use('fivethirtyeight')

# %%
style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
a2=[4,5,9,3,5]
b2=[4,7,4,1,2]

plt.plot(a,b,"black",linewidth=5,label='awikwok')
plt.plot(a2,b2,"green",linewidth=5,label='akoakoqo')

plt.legend()

plt.title('garis')
plt.xlabel('aaa')
plt.ylabel('yyy')

plt.show()

# %%
plt.bar(a,b,label='gatau',color='pink')
plt.bar(a2,b2,label='gatau1',color='purple')
plt.xlabel('pink')
plt.ylabel('purple')

plt.legend()
plt.title('color')

plt.show()

# %%
plt.bar(['hendery','yuta','kai','johnny','nanami'],b2,label='cogan',color='lightgreen')
plt.xlabel('pink')
plt.ylabel('purple')

plt.legend()
plt.title('color')

plt.show()

# %%
rand=np.random.RandomState()
nct= rand.randint(1,20,size=127)

bins=[3,5,10,15,20]
plt.hist(nct,bins,histtype='bar',color='lightgreen',rwidth=0.5)

plt.show()

# %%
plt.scatter(a,b,label='titik', color='blue')
plt.legend()
plt.show()

# %%
day=[1,2,3,4,5]

sleep=[1,24,6,8,8]
eat=[6,34,67,3,5]
work=[24,5,7,5,32]
play=[2,4,87,54,3]

plt.plot([],[],color='lightgreen',label='sleep',linewidth=5)
plt.plot([],[],color='lightblue',label='eat',linewidth=5)
plt.plot([],[],color='pink',label='work',linewidth=5)
plt.plot([],[],color='red',label='play',linewidth=5)

plt.stackplot(day,sleep,eat,work,play,color=['lightgreen','lightblue','pink','red'])

plt.show()

# %%
sls=[4,5,7,3,2]
act=['sleep','eat','fangirl','play','work']
col=['r','c','g','w','b']

plt.pie(sls,labels=act,colors=col,startangle=90,shadow=False,explode=(0,0,0.3,0,0),autopct='%1.1f%%')

plt.show()

# %%
##pandas

my_series=pd.Series([1,2,3,'asgsd',4.5,-99])
my_series
my_series[3]
type(my_series)
# Out:
# pandas.core.series.Series

# %%
my_series=pd.Series([1,2,3,'asgsd',4.5,-99],index=['a','b','c','d','e','f'])
my_series['d']
# Out:
# 'asgsd'

# %%
lbl=['usa','uae','italy']
ser=pd.Series(lbl)
print(ser)
print(lbl)
# Out:
# 0      usa
# 1      uae
# 2    italy
# dtype: object
# ['usa', 'uae', 'italy']

# %%
dict={'usa':100, 'uae':50, 'italy':90}
ser1=pd.Series(dict)
print(ser1)
# Out:
# usa      100
# uae       50
# italy     90
# dtype: int64

# %%
from numpy.random import randn

# %%
df=pd.DataFrame(randn(6,4),['a','b','c','d','e',9],['hh','gfd','ds','sa']) #randn harus sebesar data frame
df
# Out:
#          hh       gfd        ds        sa
# a -0.655632 -0.769110 -0.576946  0.339289
# b  0.105265  1.890813  0.220773 -0.137580
# c -0.397040 -2.072432  0.179761 -1.697239
# d -0.871130 -1.524421 -1.321115 -0.298853
# e -1.753144 -2.285179  0.248080  0.241589
# 9 -0.010641  1.796466  1.635725 -0.570782

# %%
df['hh']
# Out:
# a   -0.074931
# b    0.816873
# c   -0.488951
# d   -0.520818
# e   -0.259253
# Name: hh, dtype: float64

# %%
df[['hh','sa']]
# Out:
#          hh        sa
# a -0.655632  0.339289
# b  0.105265 -0.137580
# c -0.397040 -1.697239
# d -0.871130 -0.298853
# e -1.753144  0.241589
# 9 -0.010641 -0.570782

# %%
df['hew']=df['hh']-df['sa']
df['hew']
# Out:
# a   -0.994921
# b    0.242845
# c    1.300199
# d   -0.572278
# e   -1.994733
# 9    0.560141
# Name: hew, dtype: float64

# %%
df.loc[9]
# Out:
# hh    -0.010641
# gfd    1.796466
# ds     1.635725
# sa    -0.570782
# hew    0.560141
# Name: 9, dtype: float64

# %%
df.iloc[1]
# Out:
# hh     0.105265
# gfd    1.890813
# ds     0.220773
# sa    -0.137580
# hew    0.242845
# Name: b, dtype: float64

# %%
df.loc['a','hh']
# Out:
# -0.6556321362018146

# %%
df[(df['hh']<0)&(df['hew']<0)]
# Out:
#          hh       gfd        ds        sa       hew
# a -0.655632 -0.769110 -0.576946  0.339289 -0.994921
# d -0.871130 -1.524421 -1.321115 -0.298853 -0.572278
# e -1.753144 -2.285179  0.248080  0.241589 -1.994733

# %%
city='ca bw uae or yu ko'.split()
city
# Out:
# ['ca', 'bw', 'uae', 'or', 'yu', 'ko']

# %%
df['state']=city
df
# Out:
#          hh       gfd        ds        sa       hew state
# a -0.655632 -0.769110 -0.576946  0.339289 -0.994921    ca
# b  0.105265  1.890813  0.220773 -0.137580  0.242845    bw
# c -0.397040 -2.072432  0.179761 -1.697239  1.300199   uae
# d -0.871130 -1.524421 -1.321115 -0.298853 -0.572278    or
# e -1.753144 -2.285179  0.248080  0.241589 -1.994733    yu
# 9 -0.010641  1.796466  1.635725 -0.570782  0.560141    ko

# %%
df.index.names=['ASSDWWSD']
df
# Out:
#                 hh       gfd        ds        sa       hew state
# ASSDWWSD
# a        -0.655632 -0.769110 -0.576946  0.339289 -0.994921    ca
# b         0.105265  1.890813  0.220773 -0.137580  0.242845    bw
# c        -0.397040 -2.072432  0.179761 -1.697239  1.300199   uae
# d        -0.871130 -1.524421 -1.321115 -0.298853 -0.572278    or
# e        -1.753144 -2.285179  0.248080  0.241589 -1.994733    yu
# 9        -0.010641  1.796466  1.635725 -0.570782  0.560141    ko

# %%
outside='g1 g1 g1 g2 g2 g2'.split()
outside=['g1','g1','g1','g2','g2','g2']
inside=[1,2,3,1,2,3]
hier_idx=list(zip(outside,inside))
h_idx=pd.MultiIndex.from_tuples(hier_idx)

h_idx
# Out:
# MultiIndex([('g1', 1),
#             ('g1', 2),
#             ('g1', 3),
#             ('g2', 1),
#             ('g2', 2),
#             ('g2', 3)],
#            )

# %%
dt=pd.DataFrame(randn(6,2),hier_idx,['a','b'])
dt
# Out:
#                 a         b
# (g1, 1) -0.706596  1.786835
# (g1, 2) -1.217931  1.675246
# (g1, 3)  1.153470  0.045957
# (g2, 1) -0.217116 -1.681798
# (g2, 2) -0.063310  0.091770
# (g2, 3) -1.455414  1.498044

# %%
dt.index.names=['grp']
dt
# Out:
#                 a         b
# grp
# (g1, 1) -0.706596  1.786835
# (g1, 2) -1.217931  1.675246
# (g1, 3)  1.153470  0.045957
# (g2, 1) -0.217116 -1.681798
# (g2, 2) -0.063310  0.091770
# (g2, 3) -1.455414  1.498044

# %%
def fdt(isi):
    data1=np.array(isi)
    if data1 is None or len(data1)==0 or len(data1[0])==0:
        return print('data tidak ada')
    else:
        return pd.DataFrame(data1[1:,1:],
                           index=data1[1:0],columns=data1[0,1:])

# %%
#data1=[]
data1=[['','a','b'],'cy jn jh tn hd xj'.split(),'cy jn jh tn hd xj'.split()]
data1
#fdt(data1)
# Out:
# [['', 'a', 'b'],
#  ['cy', 'jn', 'jh', 'tn', 'hd', 'xj'],
#  ['cy', 'jn', 'jh', 'tn', 'hd', 'xj']]

# %%
a={'nama':['hc','js','jn','jh','hd','xj'],
  'kelas':['dr','dr','ilc','ilc','wv','wv'],
  'nilai':[80,100,75,60,90,50]}
a
# Out:
# {'nama': ['hc', 'js', 'jn', 'jh', 'hd', 'xj'],
#  'kelas': ['dr', 'dr', 'ilc', 'ilc', 'wv', 'wv'],
#  'nilai': [80, 100, 75, 60, 90, 50]}

# %%
nct=pd.DataFrame(a)
nct
# Out:
#   nama kelas  nilai
# 0   hc    dr     80
# 1   js    dr    100
# 2   jn   ilc     75
# 3   jh   ilc     60
# 4   hd    wv     90
# 5   xj    wv     50

# %%
nct.groupby('kelas').min()
# Out:
#       nama  nilai
# kelas
# dr      hc     80
# ilc     jh     60
# wv      hd     50

# %%
nct.head(2)
# Out:
#   nama kelas  nilai
# 0   hc    dr     80
# 1   js    dr    100

# %%
nct.describe()
# Out:
#             nilai
# count    6.000000
# mean    75.833333
# std     18.551729
# min     50.000000
# 25%     63.750000
# 50%     77.500000
# 75%     87.500000
# max    100.000000

# %%
nct.groupby('kelas').describe()
# Out:
#       nilai
#       count  mean        std   min    25%   50%    75%    max
# kelas
# dr      2.0  90.0  14.142136  80.0  85.00  90.0  95.00  100.0
# ilc     2.0  67.5  10.606602  60.0  63.75  67.5  71.25   75.0
# wv      2.0  70.0  28.284271  50.0  60.00  70.0  80.00   90.0

# %%
b={'nama':['sc','mg','js','jh','xm','hs'],
  'kelas':['hh','hh','ilc','ilc','pr','pr'],
  'nilai':[80,90,45,90,90,50]}
svt=pd.DataFrame(b)

nctsvt=pd.merge(nct,svt,on='kelas')
nctsvt
# Out:
#   nama_x kelas  nilai_x nama_y  nilai_y
# 0     jn   ilc       75     js       45
# 1     jn   ilc       75     jh       90
# 2     jh   ilc       60     js       45
# 3     jh   ilc       60     jh       90

# %% [markdown]
# ## Excercise

# %% [markdown]
# 1.Show csv data in python

# %%
data=pd.read_csv('dki_jakarta - dki_jakarta.csv')
data.tail(5)
# Out:
#     TAHUN NAMA PROVINSI NAMA KABUPATEN NAMA KECAMATAN
# 24   2013   DKI JAKARTA  JAKARTA PUSAT    TANAH ABANG
# 25   2013   DKI JAKARTA  JAKARTA PUSAT    TANAH ABANG
# 26   2013   DKI JAKARTA  JAKARTA PUSAT    TANAH ABANG
# 27   2013   DKI JAKARTA  JAKARTA PUSAT    TANAH ABANG
# 28   2013   DKI JAKARTA  JAKARTA PUSAT     JOHAR BARU

# %% [markdown]
# 2.Change the contents of the csv data into a List

# %%
dki_list = data.values.tolist()
dki_list
# Out:
# [[2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'SAWAH BESAR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'SAWAH BESAR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'SAWAH BESAR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'SAWAH BESAR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'SAWAH BESAR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'KEMAYORAN'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'KEMAYORAN'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'KEMAYORAN'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'SENEN'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'SENEN'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'SENEN'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'SENEN'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'CEMPAKA PUTIH'],
# ...

# %%
tahun = data['TAHUN'].tolist()
provinsi = data['NAMA PROVINSI'].tolist()
kabupaten = data['NAMA KABUPATEN'].tolist()
kecamatan = data['NAMA KECAMATAN'].tolist()

print('tahun',tahun,
      '\n\nprovinsi',provinsi,
      '\n\nkabupaten',kabupaten,
      '\n\nkecamatan',kecamatan)
# Out:
# tahun [2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013, 2013]
#
# provinsi ['DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA', 'DKI JAKARTA']
#
# ...

# %% [markdown]
# 3.Show data list in index [0: 5]

# %%
dki_list[0:5]
# Out:
# [[2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR'],
#  [2013, 'DKI JAKARTA', 'JAKARTA PUSAT', 'GAMBIR']]

# %% [markdown]
# 4.Change the list in a dataframe

# %%
dict = {'TAHUN': tahun, 
        'NAMA PROVINSI': provinsi, 
        'NAMA KABUPATEN': kabupaten,
        'NAMA KECAMATAN':kecamatan}
df = pd.DataFrame(dict) 
    
df.head(5)
# Out:
#    TAHUN NAMA PROVINSI NAMA KABUPATEN NAMA KECAMATAN
# 0   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR
# 1   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR
# 2   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR
# 3   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR
# 4   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR

# %% [markdown]
# 5.Change the format of the letters in the subdistrict column to lower

# %%
df['NAMA KECAMATAN']=(df['NAMA KECAMATAN'].str.lower())

df
# Out:
#     TAHUN NAMA PROVINSI NAMA KABUPATEN NAMA KECAMATAN
# 0    2013   DKI JAKARTA  JAKARTA PUSAT         gambir
# 1    2013   DKI JAKARTA  JAKARTA PUSAT         gambir
# 2    2013   DKI JAKARTA  JAKARTA PUSAT         gambir
# 3    2013   DKI JAKARTA  JAKARTA PUSAT         gambir
# 4    2013   DKI JAKARTA  JAKARTA PUSAT         gambir
# 5    2013   DKI JAKARTA  JAKARTA PUSAT    sawah besar
# 6    2013   DKI JAKARTA  JAKARTA PUSAT    sawah besar
# 7    2013   DKI JAKARTA  JAKARTA PUSAT    sawah besar
# 8    2013   DKI JAKARTA  JAKARTA PUSAT    sawah besar
# 9    2013   DKI JAKARTA  JAKARTA PUSAT    sawah besar
# 10   2013   DKI JAKARTA  JAKARTA PUSAT      kemayoran
# 11   2013   DKI JAKARTA  JAKARTA PUSAT      kemayoran
# 12   2013   DKI JAKARTA  JAKARTA PUSAT      kemayoran
# 13   2013   DKI JAKARTA  JAKARTA PUSAT          senen
# 14   2013   DKI JAKARTA  JAKARTA PUSAT          senen
# 15   2013   DKI JAKARTA  JAKARTA PUSAT          senen
# ...

# %% [markdown]
# 6.Then display the entire data that only has the criteria for the Gambir district.

# %%
print(data[data['NAMA KECAMATAN'].str.contains('GAMBIR')])
# Out:
#    TAHUN NAMA PROVINSI NAMA KABUPATEN NAMA KECAMATAN
# 0   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR
# 1   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR
# 2   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR
# 3   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR
# 4   2013   DKI JAKARTA  JAKARTA PUSAT         GAMBIR

# %% [markdown]
# 7.Then display all unique data only

# %%
print(data['TAHUN'].unique(),'\n', 
      data['NAMA PROVINSI'].unique(),'\n',
      data['NAMA KABUPATEN'].unique(),'\n',
      data['NAMA KECAMATAN'].unique())
# Out:
# [2013]
#  ['DKI JAKARTA']
#  ['JAKARTA PUSAT']
#  ['GAMBIR' 'SAWAH BESAR' 'KEMAYORAN' 'SENEN' 'CEMPAKA PUTIH' 'MENTENG'
#  'TANAH ABANG' 'JOHAR BARU']
